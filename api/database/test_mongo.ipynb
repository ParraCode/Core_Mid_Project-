# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import os

load_dotenv()
username = os.getenv("MONGO_USER")
password = os.getenv("MONGO_PASSWORD")
URL = f"mongodb+srv://{username}:{password}@parracode.p3gyj.mongodb.net"
db = MongoClient(URL).get_database("parracode_mid_project")
covid = db['covid']
covid

# %%
load_dotenv()
username = os.getenv("MONGO_USER")
password = os.getenv("MONGO_PASSWORD")
URL = f"mongodb+srv://{username}:{password}@parracode.p3gyj.mongodb.net"
db = MongoClient(URL).get_database("parracode_mid_project")
covid = db['covid']
covid
# Out:
# Collection(Database(MongoClient(host=['parracode-shard-00-01.p3gyj.mongodb.net:27017', 'parracode-shard-00-00.p3gyj.mongodb.net:27017', 'parracode-shard-00-02.p3gyj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-vw9mvz-shard-0', tls=True), 'parracode_mid_project'), 'covid')

# %%
filter={
    'country':'Spain'
}

result = covid.find(filter=filter)

list(result)
# Out:
# [{'_id': ObjectId('61ce3ed169d12c8bb2b1a6ee'),
#   '': 17816,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 5, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 5,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 813412,
#   'Deaths': 32225,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10949,
#   'IcuOccupancy': 1580},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6ef'),
#   '': 17817,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 6, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 6,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 825410,
#   'Deaths': 32486,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10696,
#   'IcuOccupancy': 1544},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f0'),
#   '': 17818,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 7, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 7,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 835901,
#   'Deaths': 32562,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10662,
#   'IcuOccupancy': 1568},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f1'),
#   '': 17819,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 8, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 8,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 848324,
#   'Deaths': 32688,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10645,
#   'IcuOccupancy': 1585},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f2'),
#   '': 17820,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 9, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 9,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 861112,
#   'Deaths': 32929,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10554,
#   'IcuOccupancy': 1590},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f3'),
#   '': 17821,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 10, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 10,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 861112,
#   'Deaths': 32929,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f4'),
#   '': 17822,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 11, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 41,
#   'day': 11,
#   'yearWeek': '2020-41',
#   'population': 47332614,
#   'confirmed': 861112,
#   'Deaths': 32929,
#   'recovered': 150376,
#   'testDone': 796417,
#   'testingRate': Decimal128('1682.6'),
#   'positivityRate': Decimal128('9.76'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f5'),
#   '': 17823,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 12, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 12,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 888968,
#   'Deaths': 33124,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 10109,
#   'IcuOccupancy': 1546},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f6'),
#   '': 17824,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 13, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 13,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 896086,
#   'Deaths': 33204,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11297,
#   'IcuOccupancy': 1595},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f7'),
#   '': 17825,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 14, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 14,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 908056,
#   'Deaths': 33413,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11671,
#   'IcuOccupancy': 1652},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f8'),
#   '': 17826,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 15, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 15,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 921374,
#   'Deaths': 33553,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11692,
#   'IcuOccupancy': 1702},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6f9'),
#   '': 17827,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 16, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 16,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 936560,
#   'Deaths': 33775,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11784,
#   'IcuOccupancy': 1768},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6fa'),
#   '': 17828,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 17, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 17,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 936560,
#   'Deaths': 33775,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6fb'),
#   '': 17829,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 18, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 42,
#   'day': 18,
#   'yearWeek': '2020-42',
#   'population': 47332614,
#   'confirmed': 936560,
#   'Deaths': 33775,
#   'recovered': 150376,
#   'testDone': 829266,
#   'testingRate': Decimal128('1752.0'),
#   'positivityRate': Decimal128('11.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6fc'),
#   '': 17830,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 19, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 19,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 974449,
#   'Deaths': 33992,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 12945,
#   'IcuOccupancy': 1857},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6fd'),
#   '': 17831,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 20, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 20,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 988322,
#   'Deaths': 34210,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 13288,
#   'IcuOccupancy': 1911},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6fe'),
#   '': 17832,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 21, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 21,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 1005295,
#   'Deaths': 34366,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 13698,
#   'IcuOccupancy': 1930},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a6ff'),
#   '': 17833,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 22, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 22,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 1026281,
#   'Deaths': 34521,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 14160,
#   'IcuOccupancy': 1966},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a700'),
#   '': 17834,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 23, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 23,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 1046132,
#   'Deaths': 34752,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 14539,
#   'IcuOccupancy': 2031},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a701'),
#   '': 17835,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 24, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 24,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 1046132,
#   'Deaths': 34752,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a702'),
#   '': 17836,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 25, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 43,
#   'day': 25,
#   'yearWeek': '2020-43',
#   'population': 47332614,
#   'confirmed': 1046132,
#   'Deaths': 34752,
#   'recovered': 150376,
#   'testDone': 1073926,
#   'testingRate': Decimal128('2268.89'),
#   'positivityRate': Decimal128('12.63'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a703'),
#   '': 17837,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 26, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 26,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1098320,
#   'Deaths': 35031,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 16008,
#   'IcuOccupancy': 2163},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a704'),
#   '': 17838,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 27, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 27,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1116738,
#   'Deaths': 35298,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 16696,
#   'IcuOccupancy': 2292},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a705'),
#   '': 17839,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 28, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 28,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1136503,
#   'Deaths': 35466,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 17073,
#   'IcuOccupancy': 2368},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a706'),
#   '': 17840,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 29, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 29,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1160083,
#   'Deaths': 35639,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 17520,
#   'IcuOccupancy': 2404},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a707'),
#   '': 17841,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 30, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 30,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1185678,
#   'Deaths': 35878,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 18162,
#   'IcuOccupancy': 2482},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a708'),
#   '': 17842,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 10, 31, 0, 0),
#   'year': 2020,
#   'month': 10,
#   'week': 44,
#   'day': 31,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1185678,
#   'Deaths': 35878,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a709'),
#   '': 17843,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 1, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 44,
#   'day': 1,
#   'yearWeek': '2020-44',
#   'population': 47332614,
#   'confirmed': 1185678,
#   'Deaths': 35878,
#   'recovered': 150376,
#   'testDone': 1220897,
#   'testingRate': Decimal128('2579.4'),
#   'positivityRate': Decimal128('11.92'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70a'),
#   '': 17844,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 2, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 2,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1240697,
#   'Deaths': 36257,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 19170,
#   'IcuOccupancy': 2650},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70b'),
#   '': 17845,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 3, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 3,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1259366,
#   'Deaths': 36495,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 19943,
#   'IcuOccupancy': 2754},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70c'),
#   '': 17846,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 4, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 4,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1284408,
#   'Deaths': 38118,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20325,
#   'IcuOccupancy': 2786},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70d'),
#   '': 17847,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 5, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 5,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1306316,
#   'Deaths': 38486,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20281,
#   'IcuOccupancy': 2802},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70e'),
#   '': 17848,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 6, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 6,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1328832,
#   'Deaths': 38833,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20239,
#   'IcuOccupancy': 2863},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a70f'),
#   '': 17849,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 7, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 7,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1328832,
#   'Deaths': 38833,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a710'),
#   '': 17850,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 8, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 45,
#   'day': 8,
#   'yearWeek': '2020-45',
#   'population': 47332614,
#   'confirmed': 1328832,
#   'Deaths': 38833,
#   'recovered': 150376,
#   'testDone': 1147694,
#   'testingRate': Decimal128('2424.74'),
#   'positivityRate': Decimal128('11.61'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a711'),
#   '': 17851,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 9, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 9,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1381218,
#   'Deaths': 39345,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 21029,
#   'IcuOccupancy': 3007},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a712'),
#   '': 17852,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 10, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 10,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1381218,
#   'Deaths': 39345,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20943,
#   'IcuOccupancy': 3064},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a713'),
#   '': 17853,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 11, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 11,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1417709,
#   'Deaths': 40105,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 21051,
#   'IcuOccupancy': 3093},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a714'),
#   '': 17854,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 12, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 12,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1437220,
#   'Deaths': 40461,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20525,
#   'IcuOccupancy': 3123},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a715'),
#   '': 17855,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 13, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 13,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1458591,
#   'Deaths': 40769,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20296,
#   'IcuOccupancy': 3125},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a716'),
#   '': 17856,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 14, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 14,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1458591,
#   'Deaths': 40769,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a717'),
#   '': 17857,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 15, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 46,
#   'day': 15,
#   'yearWeek': '2020-46',
#   'population': 47332614,
#   'confirmed': 1458591,
#   'Deaths': 40769,
#   'recovered': 150376,
#   'testDone': 1132881,
#   'testingRate': Decimal128('2393.45'),
#   'positivityRate': Decimal128('9.89'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a718'),
#   '': 17858,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 16, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 16,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1496864,
#   'Deaths': 41253,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20452,
#   'IcuOccupancy': 3156},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a719'),
#   '': 17859,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 17, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 17,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1510023,
#   'Deaths': 41688,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 20007,
#   'IcuOccupancy': 3127},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71a'),
#   '': 17860,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 18, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 18,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1525341,
#   'Deaths': 42039,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 19403,
#   'IcuOccupancy': 3120},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71b'),
#   '': 17861,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 19, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 19,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1541574,
#   'Deaths': 42291,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 18961,
#   'IcuOccupancy': 3125},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71c'),
#   '': 17862,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 20, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 20,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1556730,
#   'Deaths': 42619,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 17963,
#   'IcuOccupancy': 3054},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71d'),
#   '': 17863,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 21, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 21,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1556730,
#   'Deaths': 42619,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71e'),
#   '': 17864,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 22, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 47,
#   'day': 22,
#   'yearWeek': '2020-47',
#   'population': 47332614,
#   'confirmed': 1556730,
#   'Deaths': 42619,
#   'recovered': 150376,
#   'testDone': 990637,
#   'testingRate': Decimal128('2092.93'),
#   'positivityRate': Decimal128('8.2'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a71f'),
#   '': 17865,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 23, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 23,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1582616,
#   'Deaths': 43131,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 17695,
#   'IcuOccupancy': 2922},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a720'),
#   '': 17866,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 24, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 24,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1594844,
#   'Deaths': 43668,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 16701,
#   'IcuOccupancy': 2853},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a721'),
#   '': 17867,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 25, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 25,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1605066,
#   'Deaths': 44037,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 15986,
#   'IcuOccupancy': 2838},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a722'),
#   '': 17868,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 26, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 26,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1617355,
#   'Deaths': 44374,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 15316,
#   'IcuOccupancy': 2815},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a723'),
#   '': 17869,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 27, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 27,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1628208,
#   'Deaths': 44668,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 14819,
#   'IcuOccupancy': 2777},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a724'),
#   '': 17870,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 28, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 28,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1628208,
#   'Deaths': 44668,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a725'),
#   '': 17871,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 29, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 48,
#   'day': 29,
#   'yearWeek': '2020-48',
#   'population': 47332614,
#   'confirmed': 1628208,
#   'Deaths': 44668,
#   'recovered': 150376,
#   'testDone': 908166,
#   'testingRate': Decimal128('1918.69'),
#   'positivityRate': Decimal128('6.45'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a726'),
#   '': 17872,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 11, 30, 0, 0),
#   'year': 2020,
#   'month': 11,
#   'week': 49,
#   'day': 30,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1648187,
#   'Deaths': 45069,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 14503,
#   'IcuOccupancy': 2629},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a727'),
#   '': 17873,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 1, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 1,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1656444,
#   'Deaths': 45511,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 14243,
#   'IcuOccupancy': 2578},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a728'),
#   '': 17874,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 2, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 2,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1665775,
#   'Deaths': 45784,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 13567,
#   'IcuOccupancy': 2485},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a729'),
#   '': 17875,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 3, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 3,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1675902,
#   'Deaths': 46038,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 13063,
#   'IcuOccupancy': 2440},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72a'),
#   '': 17876,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 4, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 4,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1684647,
#   'Deaths': 46252,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 12552,
#   'IcuOccupancy': 2371},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72b'),
#   '': 17877,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 5, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 5,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1684647,
#   'Deaths': 46252,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72c'),
#   '': 17878,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 6, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 49,
#   'day': 6,
#   'yearWeek': '2020-49',
#   'population': 47332614,
#   'confirmed': 1684647,
#   'Deaths': 46252,
#   'recovered': 150376,
#   'testDone': 875084,
#   'testingRate': Decimal128('1848.8'),
#   'positivityRate': Decimal128('5.78'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72d'),
#   '': 17879,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 7, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 7,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1702328,
#   'Deaths': 46646,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72e'),
#   '': 17880,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 8, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 8,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1702328,
#   'Deaths': 46646,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a72f'),
#   '': 17881,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 9, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 9,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1712101,
#   'Deaths': 47019,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 12158,
#   'IcuOccupancy': 2179},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a730'),
#   '': 17882,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 10, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 10,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1720056,
#   'Deaths': 47344,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11965,
#   'IcuOccupancy': 2158},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a731'),
#   '': 17883,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 11, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 11,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1730575,
#   'Deaths': 47624,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11648,
#   'IcuOccupancy': 2100},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a732'),
#   '': 17884,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 12, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 12,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1730575,
#   'Deaths': 47624,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a733'),
#   '': 17885,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 13, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 50,
#   'day': 13,
#   'yearWeek': '2020-50',
#   'population': 47332614,
#   'confirmed': 1730575,
#   'Deaths': 47624,
#   'recovered': 150376,
#   'testDone': 785052,
#   'testingRate': Decimal128('1658.59'),
#   'positivityRate': Decimal128('6.44'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a734'),
#   '': 17886,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 14, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 14,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1751884,
#   'Deaths': 48013,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11736,
#   'IcuOccupancy': 2068},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a735'),
#   '': 17887,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 15, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 15,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1762212,
#   'Deaths': 48401,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11736,
#   'IcuOccupancy': 2027},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a736'),
#   '': 17888,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 16, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 16,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1773290,
#   'Deaths': 48596,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11346,
#   'IcuOccupancy': 1964},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a737'),
#   '': 17889,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 17, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 17,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1785421,
#   'Deaths': 48777,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11336,
#   'IcuOccupancy': 1955},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a738'),
#   '': 17890,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 18, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 18,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1797236,
#   'Deaths': 48926,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11224,
#   'IcuOccupancy': 1920},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a739'),
#   '': 17891,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 19, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 19,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1797236,
#   'Deaths': 48926,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a73a'),
#   '': 17892,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 20, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 51,
#   'day': 20,
#   'yearWeek': '2020-51',
#   'population': 47332614,
#   'confirmed': 1797236,
#   'Deaths': 48926,
#   'recovered': 150376,
#   'testDone': 976158,
#   'testingRate': Decimal128('2062.34'),
#   'positivityRate': Decimal128('7.0'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a73b'),
#   '': 17893,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 21, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 52,
#   'day': 21,
#   'yearWeek': '2020-52',
#   'population': 47332614,
#   'confirmed': 1819249,
#   'Deaths': 49260,
#   'recovered': 150376,
#   'testDone': 855268,
#   'testingRate': Decimal128('1806.93'),
#   'positivityRate': Decimal128('7.73'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11431,
#   'IcuOccupancy': 1944},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a73c'),
#   '': 17894,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 22, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 52,
#   'day': 22,
#   'yearWeek': '2020-52',
#   'population': 47332614,
#   'confirmed': 1829903,
#   'Deaths': 49520,
#   'recovered': 150376,
#   'testDone': 855268,
#   'testingRate': Decimal128('1806.93'),
#   'positivityRate': Decimal128('7.73'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11500,
#   'IcuOccupancy': 1906},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a73d'),
#   '': 17895,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 23, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 52,
#   'day': 23,
#   'yearWeek': '2020-52',
#   'population': 47332614,
#   'confirmed': 1842289,
#   'Deaths': 49698,
#   'recovered': 150376,
#   'testDone': 855268,
#   'testingRate': Decimal128('1806.93'),
#   'positivityRate': Decimal128('7.73'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 11328,
#   'IcuOccupancy': 1932},
#  {'_id': ObjectId('61ce3ed169d12c8bb2b1a73e'),
#   '': 17896,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2020, 12, 24, 0, 0),
#   'year': 2020,
#   'month': 12,
#   'week': 52,
#   'day': 24,
#   'yearWeek': '2020-52',
# ...
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 23, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 23,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5103315,
#   'Deaths': 87866,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88a'),
#   '': 18228,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 24, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 24,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5111842,
#   'Deaths': 87904,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88b'),
#   '': 18229,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 25, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 25,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5121100,
#   'Deaths': 87931,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88c'),
#   '': 18230,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 26, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 26,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5131012,
#   'Deaths': 87955,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88d'),
#   '': 18231,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 27, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 27,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5131012,
#   'Deaths': 87955,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88e'),
#   '': 18232,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 28, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 47,
#   'day': 28,
#   'yearWeek': '2021-47',
#   'population': 47332614,
#   'confirmed': 5131012,
#   'Deaths': 87955,
#   'recovered': 0,
#   'testDone': 890328,
#   'testingRate': Decimal128('1881.0'),
#   'positivityRate': Decimal128('6.6'),
#   'dosesReceived': 1137600,
#   'dosesExported': 0,
#   'firstDose': 76265,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a88f'),
#   '': 18233,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 29, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 48,
#   'day': 29,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5153923,
#   'Deaths': 88008,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a890'),
#   '': 18234,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 11, 30, 0, 0),
#   'year': 2021,
#   'month': 11,
#   'week': 48,
#   'day': 30,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5164184,
#   'Deaths': 88052,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a891'),
#   '': 18235,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 1, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 48,
#   'day': 1,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5174720,
#   'Deaths': 88080,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a892'),
#   '': 18236,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 2, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 48,
#   'day': 2,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5189220,
#   'Deaths': 88122,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a893'),
#   '': 18237,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 3, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 48,
#   'day': 3,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5202958,
#   'Deaths': 88159,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a894'),
#   '': 18238,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 4, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 48,
#   'day': 4,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5202958,
#   'Deaths': 88159,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a895'),
#   '': 18239,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 5, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 48,
#   'day': 5,
#   'yearWeek': '2021-48',
#   'population': 47332614,
#   'confirmed': 5202958,
#   'Deaths': 88159,
#   'recovered': 0,
#   'testDone': 1097895,
#   'testingRate': Decimal128('2319.53'),
#   'positivityRate': Decimal128('8.02'),
#   'dosesReceived': 1138600,
#   'dosesExported': 0,
#   'firstDose': 100714,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a896'),
#   '': 18240,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 6, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 6,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5202958,
#   'Deaths': 88159,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a897'),
#   '': 18241,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 7, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 7,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5246766,
#   'Deaths': 88237,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a898'),
#   '': 18242,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 8, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 8,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5246766,
#   'Deaths': 88237,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a899'),
#   '': 18243,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 9, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 9,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5273178,
#   'Deaths': 88321,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89a'),
#   '': 18244,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 10, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 10,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5290273,
#   'Deaths': 88380,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89b'),
#   '': 18245,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 11, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 11,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5290190,
#   'Deaths': 88381,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89c'),
#   '': 18246,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 12, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 49,
#   'day': 12,
#   'yearWeek': '2021-49',
#   'population': 47332614,
#   'confirmed': 5290190,
#   'Deaths': 88381,
#   'recovered': 0,
#   'testDone': 1030473,
#   'testingRate': Decimal128('2177.09'),
#   'positivityRate': Decimal128('10.85'),
#   'dosesReceived': 7640520,
#   'dosesExported': 0,
#   'firstDose': 69612,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89d'),
#   '': 18247,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 20, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 20,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5535231,
#   'Deaths': 88793,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89e'),
#   '': 18248,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 21, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 21,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5585054,
#   'Deaths': 88887,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a89f'),
#   '': 18249,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 22, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 22,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5645095,
#   'Deaths': 88937,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a8a0'),
#   '': 18250,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 23, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 23,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5718007,
#   'Deaths': 89019,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a8a1'),
#   '': 18251,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 24, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 24,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5718007,
#   'Deaths': 89019,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a8a2'),
#   '': 18252,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 25, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 25,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5718007,
#   'Deaths': 89019,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0},
#  {'_id': ObjectId('61ce3ed269d12c8bb2b1a8a3'),
#   '': 18253,
#   'country': 'Spain',
#   'latitude': Decimal128('40.4'),
#   'longitude': Decimal128('-3.683333'),
#   'date': datetime.datetime(2021, 12, 26, 0, 0),
#   'year': 2021,
#   'month': 12,
#   'week': 51,
#   'day': 26,
#   'yearWeek': '2021-51',
#   'population': 47332614,
#   'confirmed': 5718007,
#   'Deaths': 89019,
#   'recovered': 0,
#   'testDone': 2288693,
#   'testingRate': Decimal128('4835.34'),
#   'positivityRate': Decimal128('15.36'),
#   'dosesReceived': 0,
#   'dosesExported': 0,
#   'firstDose': 0,
#   'hospitalOccupancy': 0,
#   'IcuOccupancy': 0}]
